# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, I will show what i have learned in this course.

# %% [markdown]
# --------
# **Some of the popular languages that Data Scientists use are:**
# 1. python
# 2. R language
# 3. SQL

# %% [markdown]
# -------
# *Some of the commonly used libraries used by Data Scientists include:*
# 1. Pandas
# 2. Numpy
# 3. Seaborn
# 4. Keras

# %% [markdown]
# --------
# | Data Science Tools |
# |--------------------|
# | Apache Spark |
# | Jupyter Labs |
# | R-Studio |

# %% [markdown]
# --------
# ### Below are a few examples of evaluating arithmetic expressions in Python
# 1. "+"
# 2. "-"
# 3. "*"
# 4. "/"

# %%
# This a simple arithmetic expression to mutiply then add integers
print ((3+4)*2)
# Out:
# 14

# %%
#This will convert 200 minutes to hours by diving by 60
min=200
hours=min/60
print(min , "minutes equal" , hours , "hours")
# Out:
# 200 minutes equal 3.3333333333333335 hours

# %% [markdown]
# **objectives**
# - the popular languages that Data Scientists use
# - the commonly used libraries used by Data Scientists
# - Data Science Tools
# - machine learning models

# %% [markdown]
# ## Author
# Mohamed Tarek
